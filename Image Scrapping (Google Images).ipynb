# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as ureq
import logging
import os

# %%
save_dir = "images/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64 ) AppleWebkit/537.36 (KHTML,like Gecko) Chrome/58.0.3029.110 Safari/537.56"}

# %%
query = "Narendra Modiji"
response = requests.get(f"https://www.google.com/search?q={query}&sca_esv=0cf4e596d1fd4e2a&sxsrf=AE3TifOm9Bu02Y_xDzitDWTvuIgLq2MJFw%3A1764062653551&source=hp&ei=vXUlabqDINmvseMP-Y_psA8&iflsig=AOw8s4IAAAAAaSWDzVkGSSvm1Z194eRSYE8M_HeAY_U2&udm=2&oq=&gs_lp=&sclient=gws-wiz=1")

# %%
print(response)
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(response.content,'html.parser')

# %%
Soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
images_tags = Soup.find_all("img")

# %%
images_tags
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3HpT-44rxttAQM0SRoCuqKQk0QNxUzs51oCzn1aj7ugBIyfdU_VRqaTIOFw&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNRHrHDA2FdmoP0XNUIvuaaZd-DtG7bvcVYzzZY-Qs6M7aZ5A27PubG8v0YCI&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQvJW6d0j9zieupQOOrIxusQF8CE6F33e0pSprdZ-pSJ3hJ1zEopUVMRBOZ3ps&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRCwqsXXRSqToNYduWBV5GUKjBmk_kn6DXrlkV-tK3TwoXKCPlnY2V3Q5Wf5w&amp;s"/>,
#  <img alt="" class="DS1iW" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTi86zcLIHIGz9x-gBPmGP_VNIKB2LJde1K0ZQhsTc7b5Nk4ececw7R0zav7CY&amp;s"/>,
# ...

# %%
len(images_tags)
# Out:
# 21

# %%
del images_tags[0]

# %%
img_data_mongo = []
for i in images_tags:
    image_url = i['src']
    image_data = requests.get(image_url).content
    mydict = {"index" : image_url,"image" : image_data}
    img_data_mongo.append(mydict)
    
    with open(os.path.join(save_dir,f"{query}_{images_tags.index(i)}.jpg"),"wb") as f:
        f.write(image_data)
